# %%
import pandas as pd 
import numpy as np
data = pd.read_csv('reward level 2.csv',engine='python')

# %%
data
# Out:
#        reward levels split  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                     25.0        50.0       100.0       250.0       500.0
# 1                      1.0         5.0        10.0        25.0        50.0
# 2                      1.0        10.0        25.0        30.0        50.0
# 3                     10.0        25.0        50.0       100.0       150.0
# 4                      5.0        25.0        50.0       100.0       250.0
# 5                      5.0        10.0        25.0        50.0       100.0
# 6                     10.0        20.0        50.0       100.0       250.0
# 7                      5.0         8.0        10.0        15.0        20.0
# 8                      1.0        20.0        35.0        50.0        60.0
# 9                      1.0         NaN         NaN         NaN         NaN
# 10                     3.0        10.0        15.0        20.0        25.0
# ...

# %%
data.insert(0, 'Average', np.mean(data, axis=1))

# %%
data
# Out:
#            Average  reward levels split  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0       632.142857                 25.0        50.0       100.0       250.0
# 1        18.200000                  1.0         5.0        10.0        25.0
# 2       556.615385                  1.0        10.0        25.0        30.0
# 3        97.500000                 10.0        25.0        50.0       100.0
# 4       275.714286                  5.0        25.0        50.0       100.0
# 5        38.000000                  5.0        10.0        25.0        50.0
# 6       275.714286                 10.0        20.0        50.0       100.0
# 7       175.666667                  5.0         8.0        10.0        15.0
# 8       337.600000                  1.0        20.0        35.0        50.0
# 9         1.000000                  1.0         NaN         NaN         NaN
# 10     1211.809524                  3.0        10.0        15.0        20.0
# ...

# %%
data.to_csv('Reward Level Data.csv')
