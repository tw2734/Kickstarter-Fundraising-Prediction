# %%
import pandas as pd 
import numpy as np
data = pd.read_csv('reward level 2.csv',engine='python')
data
# Out:
#        reward levels split  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                     25.0        50.0       100.0       250.0       500.0
# 1                      1.0         5.0        10.0        25.0        50.0
# 2                      1.0        10.0        25.0        30.0        50.0
# 3                     10.0        25.0        50.0       100.0       150.0
# 4                      5.0        25.0        50.0       100.0       250.0
# 5                      5.0        10.0        25.0        50.0       100.0
# 6                     10.0        20.0        50.0       100.0       250.0
# 7                      5.0         8.0        10.0        15.0        20.0
# 8                      1.0        20.0        35.0        50.0        60.0
# 9                      1.0         NaN         NaN         NaN         NaN
# 10                     3.0        10.0        15.0        20.0        25.0
# ...

# %%
np.std(data, axis=1)
# Out:
# 0         826.212776
# 1          17.859451
# 2        1310.428793
# 3          82.852781
# 4         336.690071
# 5          34.727511
# 6         336.658247
# 7         284.430523
# 8         488.885304
# 9           0.000000
# 10       2285.657718
# 11        196.022958
# 12         98.083679
# 13         55.646743
# 14         97.042194
# 15        382.721831
# 16        643.357587
# 17        374.699880
# 18       1599.246774
# 19       1317.526292
# 20        212.830462
# 21        162.018517
# 22        554.479235
# 23        374.561076
# 24       1530.445973
# 25          0.000000
# 26          0.000000
# 27        196.448944
# 28        815.378555
# 29       1420.550518
#             ...
# 41902     349.537595
# 41903     349.537595
# 41904     327.605231
# 41905     327.605231
# 41906     168.983891
# 41907     168.983891
# 41908     763.023293
# 41909     763.023293
# 41910     355.773805
# 41911    1184.150464
# 41912    3545.218142
# 41913     315.582511
# ...

# %%
data.insert(0, 'Std', np.std(data, axis=1))
data
# Out:
#                Std  reward levels split  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0       826.212776                 25.0        50.0       100.0       250.0
# 1        17.859451                  1.0         5.0        10.0        25.0
# 2      1310.428793                  1.0        10.0        25.0        30.0
# 3        82.852781                 10.0        25.0        50.0       100.0
# 4       336.690071                  5.0        25.0        50.0       100.0
# 5        34.727511                  5.0        10.0        25.0        50.0
# 6       336.658247                 10.0        20.0        50.0       100.0
# 7       284.430523                  5.0         8.0        10.0        15.0
# 8       488.885304                  1.0        20.0        35.0        50.0
# 9         0.000000                  1.0         NaN         NaN         NaN
# 10     2285.657718                  3.0        10.0        15.0        20.0
# ...

# %%
data.to_csv('Reward Level Data 2.csv')
